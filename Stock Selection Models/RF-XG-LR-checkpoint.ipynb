# %%
import numpy as py
import pandas as pd
import matplotlib as pl
import yfinance as yf
from pandas_datareader import data as pdr
from pandas_datareader import famafrench
#import ticker list file here
namelist=pd.read_csv("Thesis/FINALSTOCK.csv")
namelist=namelist.dropna()

# %%
namelist
# Out:
#    Ticker
# 0     JPM
# 1     BAC
# 2     WFC
# 3      MS
# 4       C
# ..    ...
# 88   CASH
# 89   NWBI
# 90   CFFN
# 91   NBTB
# 92   SYBT
#
# [93 rows x 1 columns]

# %%
#Load dataset
ticker=[]
for i in range(len(namelist.Ticker)):
    data = pdr.get_data_yahoo(str(namelist.iloc[i,0]), start="2009-01-01", end="2021-01-01")#change date to 22 days before for vol
    data=pd.DataFrame(data).drop('Volume',axis=1)
    ticker.append(data)

# %%
#match date values 
for i in range(len(ticker)):
    ticker[i]=ticker[i].reset_index()
    ticker[i]=ticker[i].dropna()
sets=list(set(ticker[i]['Date']) for i in range(len(ticker)))
missin=pd.to_datetime(list(set.union(*sets)-set.intersection(*sets)),
                         format="%Y%m%d").sort_values()

# %%
#add new row, sort,fillna(improve when have time)
for i in range(len(ticker)):
    for j in missin:
        if j in list(ticker[i]['Date']):
            pass
        else:
            ticker[i].loc[ticker[i].shape[0]]=[j,None,None,None,None,None]
            ticker[i]=ticker[i].sort_values(by=['Date'],ascending=True)

# %%
#fillna:
for i in range(len(ticker)):
    ticker[i]=ticker[i].interpolate()
    print(ticker[i].isna().sum())
    print(ticker[i].shape)
# Out:
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         1
# Low          1
# Open         1
# Close        1
# Adj Close    1
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         1
# Low          1
# Open         1
# Close        1
# Adj Close    1
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         1
# Low          1
# Open         1
# Close        1
# Adj Close    1
# dtype: int64
# (3422, 6)
# Date         0
# High         1
# Low          1
# Open         1
# Close        1
# Adj Close    1
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         1
# Low          1
# Open         1
# Close        1
# Adj Close    1
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         4
# Low          4
# Open         4
# Close        4
# Adj Close    4
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         4
# Low          4
# Open         4
# Close        4
# Adj Close    4
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         4
# Low          4
# Open         4
# Close        4
# Adj Close    4
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         1
# Low          1
# Open         1
# Close        1
# Adj Close    1
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         4
# Low          4
# Open         4
# Close        4
# Adj Close    4
# dtype: int64
# (3422, 6)
# Date         0
# High         4
# Low          4
# Open         4
# Close        4
# Adj Close    4
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         4
# Low          4
# Open         4
# Close        4
# Adj Close    4
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         2
# Low          2
# Open         2
# Close        2
# Adj Close    2
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Adj Close    0
# dtype: int64
# (3422, 6)

# %%
tickersave=ticker.copy()

# %%
ticker=tickersave.copy()

# %%
#def risk_adjusted_return: fama french 5 factor
fama=pd.read_csv('Fama.csv')
fama['Date']=pd.to_datetime(fama['Date'])

# %%
tri=[]
for i in range(len(ticker)):
    ticker[i]=ticker[i].merge(fama[['Date','RF']],on='Date')
    tri.append(py.log(ticker[i].loc[:, 'Open'] / ticker[i].loc[:, 'Close'].shift(1)) ** 2 +
                                       0.5 *py.log(ticker[i].loc[:, 'High'] / ticker[i].loc[:, 'Low']) ** 2 -
                                       (2 * py.log(2) - 1) *
                                       py.log(ticker[i].loc[:, 'Close'] / ticker[i].loc[:, 'Open']) ** 2)
    ticker[i]['Return']= ticker[i]['Adj Close'].pct_change(1)
    ticker[i]['Excess Return']=ticker[i]['Return']-ticker[i]['RF']
    ticker[i]['Volatility'] = py.sqrt(252 / 22 *
                  pd.DataFrame.rolling(py.log(ticker[i].loc[:, 'Open'] / ticker[i].loc[:, 'Close'].shift(1)) ** 2 +
                                       0.5 *py.log(ticker[i].loc[:, 'High'] / ticker[i].loc[:, 'Low']) ** 2 -
                                       (2 * py.log(2)   - 1) *
                                       py.log(ticker[i].loc[:, 'Close'] / ticker[i].loc[:, 'Open']) ** 2,
                                       window=22).sum())
    ticker[i]['Risk Adj Return']=ticker[i]['Excess Return']/ticker[i]['Volatility'].shift(1)

# %%
tri=pd.DataFrame(data=tri)
tri=tri.T
tri=tri.transform(lambda x:x**0.5)
tri.columns=namelist['Ticker']
tri['Date']=ticker[0]['Date']
tri.to_csv('Thesis/S336951_Volatility.csv')

# %%
for i in range(len(ticker)):
    ticker[i]=ticker[i][106:]

# %%
#def avr_benchmark:FOR EACH DAYY!
bm=[]
for i in range(len(ticker[0]['Return'])):
    dayavr=[]
    for j in range(len(ticker)): 
        dayavr.append(ticker[j].iloc[i,9])
    avr=sum(dayavr)/len(dayavr)
    bm.append(avr)

# %%
# def performance_rating(ticker):
for i in range(len(ticker)): 
    day_perf=[]
    for j in range(len(ticker[0])):
        if ticker[i].iloc[j,9] >= bm[j]:
            day_perf.append(1)
        else:    
            day_perf.append(0)
    ticker[i]['Performance']=day_perf

# %%
#Check distribution and Set date index
a=0
for i in range(len(ticker)):
    a=a+1
    print(a)
    #ticker[i]=ticker[i].set_index('Date')
    print(ticker[i]['Performance'].value_counts())
# Out:
# 1
# 0    2647
# 1     377
# Name: Performance, dtype: int64
# 2
# 1    1566
# 0    1458
# Name: Performance, dtype: int64
# 3
# 0    2384
# 1     640
# Name: Performance, dtype: int64
# 4
# 1    1816
# 0    1208
# Name: Performance, dtype: int64
# 5
# 1    1525
# 0    1499
# Name: Performance, dtype: int64
# 6
# 0    3024
# Name: Performance, dtype: int64
# 7
# 1    1574
# 0    1450
# Name: Performance, dtype: int64
# 8
# 0    2932
# 1      92
# Name: Performance, dtype: int64
# 9
# 0    2543
# 1     481
# Name: Performance, dtype: int64
# 10
# 0    3013
# 1      11
# Name: Performance, dtype: int64
# 11
# 0    2569
# 1     455
# Name: Performance, dtype: int64
# 12
# 0    2335
# 1     689
# Name: Performance, dtype: int64
# 13
# 0    2799
# 1     225
# Name: Performance, dtype: int64
# 14
# 0    2597
# 1     427
# Name: Performance, dtype: int64
# 15
# 1    2332
# 0     692
# Name: Performance, dtype: int64
# 16
# 0    2457
# 1     567
# Name: Performance, dtype: int64
# 17
# 0    3002
# 1      22
# Name: Performance, dtype: int64
# 18
# 0    1939
# 1    1085
# Name: Performance, dtype: int64
# 19
# 0    2753
# 1     271
# Name: Performance, dtype: int64
# 20
# 0    2881
# 1     143
# Name: Performance, dtype: int64
# 21
# 0    3001
# 1      23
# Name: Performance, dtype: int64
# 22
# 1    2088
# 0     936
# Name: Performance, dtype: int64
# 23
# 0    2967
# 1      57
# Name: Performance, dtype: int64
# 24
# 0    2815
# 1     209
# Name: Performance, dtype: int64
# 25
# 1    2358
# 0     666
# Name: Performance, dtype: int64
# 26
# 0    1933
# 1    1091
# Name: Performance, dtype: int64
# 27
# 1    2153
# 0     871
# Name: Performance, dtype: int64
# 28
# 0    2599
# 1     425
# Name: Performance, dtype: int64
# 29
# 0    3024
# Name: Performance, dtype: int64
# 30
# 0    1877
# 1    1147
# Name: Performance, dtype: int64
# 31
# 0    2592
# 1     432
# Name: Performance, dtype: int64
# 32
# 1    2104
# 0     920
# Name: Performance, dtype: int64
# 33
# 1    2251
# 0     773
# Name: Performance, dtype: int64
# 34
# 1    2562
# 0     462
# Name: Performance, dtype: int64
# 35
# 1    2450
# 0     574
# Name: Performance, dtype: int64
# 36
# 0    2989
# 1      35
# Name: Performance, dtype: int64
# 37
# 0    2116
# 1     908
# Name: Performance, dtype: int64
# 38
# 1    2670
# 0     354
# Name: Performance, dtype: int64
# 39
# 0    2806
# 1     218
# Name: Performance, dtype: int64
# 40
# 0    2096
# 1     928
# Name: Performance, dtype: int64
# 41
# 0    2928
# 1      96
# Name: Performance, dtype: int64
# 42
# 0    2089
# 1     935
# Name: Performance, dtype: int64
# 43
# 1    2721
# 0     303
# Name: Performance, dtype: int64
# 44
# 1    2692
# 0     332
# Name: Performance, dtype: int64
# 45
# 1    2657
# 0     367
# Name: Performance, dtype: int64
# 46
# 0    2980
# 1      44
# Name: Performance, dtype: int64
# 47
# 1    1625
# 0    1399
# Name: Performance, dtype: int64
# 48
# 1    1618
# 0    1406
# Name: Performance, dtype: int64
# 49
# 0    1519
# 1    1505
# Name: Performance, dtype: int64
# 50
# 0    2278
# 1     746
# Name: Performance, dtype: int64
# 51
# 1    1807
# 0    1217
# Name: Performance, dtype: int64
# 52
# 0    2463
# 1     561
# Name: Performance, dtype: int64
# 53
# 1    2435
# 0     589
# Name: Performance, dtype: int64
# 54
# 0    1967
# 1    1057
# Name: Performance, dtype: int64
# 55
# 1    1586
# 0    1438
# Name: Performance, dtype: int64
# 56
# 0    2058
# 1     966
# Name: Performance, dtype: int64
# 57
# 0    2613
# 1     411
# Name: Performance, dtype: int64
# 58
# 1    1893
# 0    1131
# Name: Performance, dtype: int64
# 59
# 1    1639
# 0    1385
# Name: Performance, dtype: int64
# 60
# 0    1515
# 1    1509
# Name: Performance, dtype: int64
# 61
# 1    2856
# 0     168
# Name: Performance, dtype: int64
# 62
# 0    2692
# 1     332
# Name: Performance, dtype: int64
# 63
# 1    1850
# 0    1174
# Name: Performance, dtype: int64
# 64
# 1    1749
# 0    1275
# Name: Performance, dtype: int64
# 65
# 1    1820
# 0    1204
# Name: Performance, dtype: int64
# 66
# 1    2266
# 0     758
# Name: Performance, dtype: int64
# 67
# 1    2260
# 0     764
# Name: Performance, dtype: int64
# 68
# 1    1527
# 0    1497
# Name: Performance, dtype: int64
# 69
# 0    2268
# 1     756
# Name: Performance, dtype: int64
# 70
# 1    1678
# 0    1346
# Name: Performance, dtype: int64
# 71
# 1    2282
# 0     742
# Name: Performance, dtype: int64
# 72
# 1    2125
# 0     899
# Name: Performance, dtype: int64
# 73
# 1    2009
# 0    1015
# Name: Performance, dtype: int64
# 74
# 1    1832
# 0    1192
# Name: Performance, dtype: int64
# 75
# 1    1830
# 0    1194
# Name: Performance, dtype: int64
# 76
# 1    2359
# 0     665
# Name: Performance, dtype: int64
# 77
# 1    2149
# 0     875
# Name: Performance, dtype: int64
# 78
# 1    2360
# 0     664
# Name: Performance, dtype: int64
# 79
# 1    2047
# 0     977
# Name: Performance, dtype: int64
# 80
# 0    1905
# 1    1119
# Name: Performance, dtype: int64
# 81
# 0    2020
# 1    1004
# Name: Performance, dtype: int64
# 82
# 0    1553
# 1    1471
# Name: Performance, dtype: int64
# 83
# 1    2621
# 0     403
# Name: Performance, dtype: int64
# 84
# 1    2373
# 0     651
# Name: Performance, dtype: int64
# 85
# 1    2293
# 0     731
# Name: Performance, dtype: int64
# 86
# 0    2179
# 1     845
# Name: Performance, dtype: int64
# 87
# 1    2541
# 0     483
# Name: Performance, dtype: int64
# 88
# 0    1921
# 1    1103
# Name: Performance, dtype: int64
# 89
# 1    2564
# 0     460
# Name: Performance, dtype: int64
# 90
# 0    2713
# 1     311
# Name: Performance, dtype: int64
# 91
# 0    2904
# 1     120
# Name: Performance, dtype: int64
# 92
# 0    1911
# 1    1113
# Name: Performance, dtype: int64
# 93
# 1    1560
# 0    1464
# Name: Performance, dtype: int64

# %% [markdown]
# II. ML

# %%
recent_data=ticker.copy()
for i in range(len(recent_data)):
    recent_data[i]=recent_data[i].iloc[:2772,-3:]

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Split Recent Training- WALK FORWARD
# Might need to slice data for the slack- update later
def split_X_y_ticker(j):
    for i in range(59):
        #Split train,test
        split=recent_data[j].iloc[42*i:252+42*(i+1),:]
        y=py.array(split.Performance.shift(-42))
        X=py.array(split.drop('Performance',axis=1))
        scale=StandardScaler()
        X=scale.fit_transform(X)
        X_tr=X[:-84]
        y_tr=y[:-84]
        X_t=X[-84:-42]
        y_t=y[-84:-42]
        #Split train,val
        X_train=[]
        X_val=[]
        y_train=[]
        y_val=[]
        for a in range(3):
            X_train.append(X_tr[:84+42*(a)].reshape(-1,2))
            y_train.append(y_tr[:84+42*(a)])
            X_val.append(X_tr[84+42*(a):84+42*(a+1)].reshape(-1,2))
            y_val.append(y_tr[84+42*(a):84+42*(a+1)])
        y_t=y_t
        X_t=X_t.reshape(-1,2)
        yield X_train,X_val,y_train,y_val,y_t,X_t,X_tr.reshape(-1,2),y_tr

# %%
def compile_for_cross_sectional_learning():
    X_train=[]
    X_val=[]
    y_train=[]
    y_val=[]
    y_t=[]
    X_t=[]
    X_tr=[]
    y_tr=[]
    for i in range(len(ticker)):
        X_train_tick=[]
        X_val_tick=[]
        y_train_tick=[]
        y_val_tick=[]
        y_t_tick=[]
        X_t_tick=[]
        X_tr_tick=[]
        y_tr_tick=[]
        a=split_X_y_ticker(i)
        for X_train_slide,X_val_slide,y_train_slide,y_val_slide,y_t_slide,X_t_slide,X_tr_slide,y_tr_slide in a:
            X_train_tick.append(X_train_slide)
            X_val_tick.append(X_val_slide)
            y_train_tick.append(y_train_slide)
            y_val_tick.append(y_val_slide)
            y_t_tick.append(y_t_slide)
            X_t_tick.append(X_t_slide)
            X_tr_tick.append(X_tr_slide)
            y_tr_tick.append(y_tr_slide )        
        X_train.append(X_train_tick)
        X_val.append(X_val_tick)
        y_train.append(y_train_tick)
        y_val.append(y_val_tick)
        y_t.append(y_t_tick)
        X_t.append(X_t_tick)
        X_tr.append(X_tr_tick)
        y_tr.append(y_tr_tick)
    X_train=py.stack([X_train[i] for i in range(len(ticker))],axis=-1)
    y_train=py.stack([y_train[i] for i in range(len(ticker))],axis=-1)
    X_val=py.stack([X_val[i] for i in range(len(ticker))],axis=-1)
    y_val=py.stack([y_val[i] for i in range(len(ticker))],axis=-1)
    X_t=py.stack([X_t[i] for i in range(len(ticker))],axis=-1)
    y_t=py.stack([y_t[i] for i in range(len(ticker))],axis=-1)
    X_tr=py.stack([X_tr[i] for i in range(len(ticker))],axis=-1)
    y_tr=py.stack([y_tr[i] for i in range(len(ticker))],axis=-1)
    return X_train,X_val,y_train,y_val,y_t,X_t,X_tr,y_tr

# %%
def CS_data():
    for i in range(len(X_train)):
        X_t.append(X_tpr[i].reshape(-1,2))
        y_t.append(y_tpr[i].reshape(-1,))
        X_tr.append(X_trpr[i].reshape(-1,2))
        y_tr.append(y_trpr[i].reshape(-1,))
        for j in range(len(X_trainpr[0])):
            X_train.append(py.concatenate(X_trainpr[i][j]))
            y_train.append(py.concatenate(y_trainpr[i][j]))
            X_val.append(X_valpr[i][j].reshape(-1,2))
            y_val.append(y_valpr[i][j].reshape(-1,))
    return X_train,X_val,y_train,y_val,y_t,X_t,X_tr,y_tr

# %%
def walk_forward_val(model):#model already defined
    Mean_Score_SV=[]
    prec=[]
    recall=[]
    f1=[]
    X_train_r,X_val_r,y_train_r,y_val_r,y_t_r,X_t_r,X_tr_r,y_tr_r=compile_for_cross_sectional_learning()
    for j in range(len(X_train_r)):
        for i in range(len(X_train_r[0])):
            X_train=py.concatenate(X_train_r[j][i])
            y_train=py.concatenate(y_train_r[j][i])
            X_val=X_val_r[j][i].reshape(-1,2)
            y_val=y_val_r[j][i].reshape(-1,)
            model.fit(X_train,y_train)
            y_pred_val=model.predict(X_val)
            Mean_Score_SV.append(accuracy_score(y_val,y_pred_val))
            prec.append(precision_score(y_val,y_pred_val)) 
            recall.append(recall_score(y_val,y_pred_val)) #Specificity
            f1.append(f1_score(y_val,y_pred_val))
    return py.mean(Mean_Score_SV),py.mean(prec),py.mean(recall),py.mean(f1)

# %%
def grid_tuning(model,params):
    best_score=0
    for param in params :
        mod=model(**param)
        acc,prec,recall, f1= walk_forward_val(mod)
        if acc > best_score:
            best_score=acc
            speci=recall
            sensi=f1
            best_param=param
        print(1)
    return best_score,speci,sensi,best_param

# %%
def model_predict(model,param):
    log=[]
    y_pred_all=[]
    mod=model(param)
    X_train_r,X_val_r,y_train_r,y_val_r,y_t_r,X_t_r,X_tr_r,y_tr_r=compile_for_cross_sectional_learning()
    for i in range(len(X_train_r)):
        X_t=X_t_r[i].reshape(-1,2)
        y_t=y_t_r[i].reshape(-1,)
        X_tr=X_tr_r[i].reshape(-1,2)
        y_tr=y_tr_r[i].reshape(-1,)
        mod.fit(X_tr,y_tr)
        y_pred=mod.predict_proba(X_t)
        y_pred_ticker.append(y_pred[:,-1])
        log.append(log_loss(y_t,y_pred,labels=[0,1]))
    y_pred_all.append(y_pred_ticker)
    return y_pred_all,log

# %% [markdown]
# 1. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score,log_loss,accuracy_score,precision_score,recall_score,f1_score

# %%
paramsRF=[{'bootstrap':True, 'n_estimators':200, 'max_depth':20,'min_samples_split':2,'min_samples_leaf':1},
         {'bootstrap':False, 'n_estimators':800, 'max_depth':60,'min_samples_split':5,'min_samples_leaf':2},
         {'bootstrap':True, 'n_estimators':1000, 'max_depth':100,'min_samples_split':10,'min_samples_leaf':4}]

# %%
best_scoreRF,speciRF,sensiRF,best_paramRF=grid_tuning(RandomForestClassifier,paramsRF)
# Out:
# 1
# 1

# %%
print(speciRF,sensiRF,best_paramRF)

# %% [markdown]
# 2. XGB

# %%
from xgboost import XGBClassifier

# %%
paramsXG=[{'learning_rate':0.2,'max_depth': 3,'gamma': 1,'reg_alpha' : 40,'reg_lambda' : 0,'colsample_bytree' : 0.5,
        'min_child_weight' : 0,'n_estimators': 180,'seed': 27},
        {'learning_rate':0.1,'max_depth': 18,'gamma': 9,'reg_alpha' : 180,'reg_lambda' : 1,'colsample_bytree' : 1,
        'min_child_weight' : 10,'n_estimators': 100,'seed': 0},
        {'learning_rate':0.1,'max_depth': 1,'gamma': 1,'reg_alpha' : 1,'reg_lambda' : 1,'colsample_bytree' : 1,
        'min_child_weight' : 1,'n_estimators': 80,'seed': 0}]

# %%
best_scoreXG,speciXG,sensiXG,paramXG=grid_tuning(XGBClassifier,paramsXG)

# %%
print(best_scoreXG,speciXG,sensiXG,paramXG)

# %% [markdown]
# 3. SVM

# %%
from sklearn.svm import SVC

# %%
paramsSV=[{'gamma':1,'C':0.1},
       {'gamma':0.01,'C':100},
       {'gamma':0.0001,'C':1000}]

# %%
best_scoreSV,speciSV,sensiSV,paramSV=grid_tuning(SVC,paramsSV)

# %%
print(best_scoreSV,speciSV,sensiSV,paramSV)
